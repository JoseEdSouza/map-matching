# %% [markdown]
# # Introdução
# Este notebook consolida a análise comparativa das ferramentas de map matching no modo online, avaliando como a taxa de amostragem das trajetórias afeta acurácia, latência, custo computacional e throughput.
#
# A análise usa os CSVs agregados em `results/` (métricas E2E, match e Prometheus) e produz tabelas e figuras para responder às perguntas de pesquisa (QP1–QP4). As figuras são salvas em `OUTPUT_PATH`, mantendo rastreabilidade dos resultados.
#
# Fluxo de trabalho:
# - carregar os dados agregados e validar consistência;
# - extrair `sample_rate` a partir do `dataset_id`;
# - agregar métricas por ferramenta e taxa de amostragem;
# - gerar gráficos e tabelas para apoiar as conclusões.
#
# Notas de leitura:
# - qualidade (F1, error_rate, Newson–Krumm) melhora com F1 alto e erros baixos;
# - latência, CPU e memória são melhores quanto menores;
# - throughput é melhor quanto maior.

# %% [markdown]
# ## Perguntas de Pesquisa
# | ID  | Pergunta de Pesquisa                                                                                                                                                | Alternativas de Resposta (como será respondida)                                                                      | Dificuldade (1–10) |
# | --- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------- | ------------------ |
# | QP1 | Qual ferramenta de map matching apresenta maior acurácia no paradigma online sob diferentes taxas de amostragem das trajetórias?                                    | Comparação de métricas de acurácia agregadas por ferramenta e taxa de amostragem, com análise estatística descritiva | **4**              |
# | QP2 | Qual ferramenta apresenta maior eficiência temporal no processamento online de trajetórias, considerando métricas de latência e variabilidade temporal (p95 e p99)? | Análise de latência média, p95 e p99 por ferramenta, com comparação direta entre distribuições                       | **3**              |
# | QP3 | Qual ferramenta apresenta maior eficiência computacional, considerando a relação entre acurácia obtida e custo computacional (uso de CPU e memória)?                | Construção de métricas compostas ou análise pareada entre acurácia e consumo médio de CPU e memória                  | **6**              |
# | QP4 | Qual ferramenta apresenta maior capacidade de processamento contínuo ao lidar com trajetórias longas e diferentes taxas de amostragem no paradigma online?          | Avaliação de throughput (pontos/s, km/s ou trajetórias/s) em cenários com trajetórias longas                         | **5**              |
# | QP5 | Qual é o impacto do uso de processamento em lotes na acurácia e no desempenho computacional das ferramentas avaliadas?                                              | Comparação direta entre cenários com e sem batch, analisando diferenças relativas nas métricas                       | **4**              |

# %% [markdown]
# ## Respostas
#
# **QP1.** Melhor acurácia no online por taxa de amostragem (média de `accuracy` por ferramenta):
#
# - sr=1.0: **barefoot** (0.9312)
# - sr=5.0: **barefoot** (0.9777)
# - sr=10.0: **barefoot** (0.9710)
# - sr=20.0: **barefoot** (0.9548)
#
# **QP2.** Eficiência temporal no online (média de latência por ferramenta):
#
# - **barefoot**: p95=306.05 ms, p99=308.05 ms, média=283.35 ms
# - graphium: p95=5456.12 ms, p99=5700.10 ms, média=4671.13 ms
#
# Resposta: **barefoot** apresenta a menor latência e variabilidade (p95/p99).
#
# **QP3.** Eficiência computacional (online), usando métrica composta `accuracy / (cpu_avg * mem_avg_mb)`:
#
# - **barefoot**: 0.03126
# - graphium: 0.00050
#
# Resposta: **barefoot** tem a melhor relação acurácia/custo computacional.
#
# **QP4.** Throughput (online) por taxa de amostragem (média de `e2e_throughput_pps`):
#
# - sr=1.0: **graphium** (32.60 pts/s)
# - sr=5.0: **graphium** (13.70 pts/s)
# - sr=10.0: **graphium** (29.61 pts/s)
# - sr=20.0: **barefoot** (1.64 pts/s)
#
# Resposta: **graphium** domina em 1.0, 5.0 e 10.0; **barefoot** aparece como melhor em 20.0.
#
# **QP5.** Impacto de batch vs non-batch (médias globais):
#
# - batch: accuracy=0.8132, cpu_avg=0.534, mem_avg=599.33 MB, p95=4041.30 ms
# - non-batch: accuracy=0.9587, cpu_avg=0.253, mem_avg=189.89 MB, p95=306.05 ms
#
# Resposta: o uso de batch **reduz acurácia** e **piora desempenho** (maior CPU/memória e p95) nos dados agregados.

# %% [markdown]
# ## Setup
# Aqui concentramos todos os imports e constantes (paths, cores e ordens), além das funções auxiliares de leitura, agregação e plotagem. Isso reduz duplicação e garante consistência entre as seções.

# %%
from pathlib import Path
import re

import duckdb
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns

# %%
RESULTS_PATH = Path.cwd() / "results"
OUTPUT_PATH = RESULTS_PATH / "figures"
OUTPUT_PATH.mkdir(parents=True, exist_ok=True)

E2E_PATH = RESULTS_PATH / "aggregated_e2e_metrics.csv"
MATCH_PATH = RESULTS_PATH / "aggregated_match_metrics.csv"
PROMETHEUS_PATH = RESULTS_PATH / "aggregated_prometheus_metrics.csv"
FINAL_PATH = RESULTS_PATH / "final_runs_table.csv"

SAMPLE_RATE_COLUMNS = ("dataset_id_mm", "dataset_id_prom")
SAMPLE_RATE_PROM_COLUMN = "dataset_id_prom"
LATENCY_COL = "e2e_avg_step_latency_ms"
E2E_TIME_COL = "duration_s"
EPS = 1e-9

TOOL_COLORS = {
    "barefoot": "tab:blue",
    "graphhopper": "tab:orange",
    "graphium": "tab:green",
    "osrm": "tab:red",
}
TOOL_ORDER = ["barefoot", "graphhopper", "graphium", "osrm"]

VARIANT_COLORS = {
    "barefoot": "tab:blue",
    "graphhopper": "tab:orange",
    "graphium (cold)": "tab:green",
    "graphium (warm)": "tab:purple",
    "osrm": "tab:red",
}
VARIANT_ORDER = ["barefoot", "graphhopper", "graphium (cold)", "graphium (warm)", "osrm"]

DEFAULT_FIGSIZE = (8, 5)

# %%
def read_csv(path: Path) -> pd.DataFrame:
    return duckdb.read_csv(path).to_df()


def add_throughput_km_per_s(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    out["e2e_throughput_km_per_s"] = out["total_gt_length"] / out["e2e_execution_time_s"]
    return out


def extract_sample_rate(dataset_id: str) -> float | None:
    match = re.search(r"sr_(\d+(\.\d+)?)", str(dataset_id))
    return float(match.group(1)) if match else None


def add_sample_rate(df: pd.DataFrame, column: str) -> pd.DataFrame:
    out = df.copy()
    out["sample_rate"] = out[column].apply(extract_sample_rate)
    return out


def add_sample_rate_from_columns(df: pd.DataFrame, columns: tuple[str, ...]) -> pd.DataFrame:
    for column in columns:
        if column in df.columns:
            return add_sample_rate(df, column)
    out = df.copy()
    out["sample_rate"] = np.nan
    return out


def resolve_output_path(file_name: str | Path | None) -> Path | None:
    if not file_name:
        return None
    file_path = Path(file_name)
    return file_path if file_path.is_absolute() else OUTPUT_PATH / file_path


def save_figure(file_name: str | Path | None) -> None:
    out_path = resolve_output_path(file_name)
    if out_path:
        plt.savefig(out_path)


def plot_line_by_group(
    df: pd.DataFrame,
    x: str,
    y: str,
    group: str,
    *,
    title: str | None = None,
    xlabel: str | None = None,
    ylabel: str | None = None,
    figsize: tuple[int, int] | None = None,
    order: list[str] | None = None,
    colors: dict[str, str] | None = None,
    file_name: str | None = None,
) -> None:
    if figsize:
        plt.figure(figsize=figsize)
    else:
        plt.figure()

    palette = colors or TOOL_COLORS
    groups = order if order is not None else df[group].dropna().unique()
    for name in groups:
        g = df[df[group] == name]
        if g.empty:
            continue
        plt.plot(
            g[x],
            g[y],
            marker="o",
            label=name,
            color=palette.get(name),
        )

    plt.xlabel(xlabel or x)
    plt.ylabel(ylabel or y)
    if title:
        plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    save_figure(file_name)
    plt.show()


def shade_color(color: str, amount: float = 0.5) -> str:
    try:
        rgb = np.array(mcolors.to_rgb(color))
        rgb = rgb * (1 - amount)
        return mcolors.to_hex(rgb)
    except ValueError:
        return color


def plot_grouped_bars_by_batch(
    agg_df: pd.DataFrame,
    value_col: str,
    ylabel: str,
    matcher_name_col: str = "matcher_name",
    title: str | None = None,
    batch_col: str = "batch_size_mm",
    log_scale: bool = False,
    file_name: str | None = None,
    order: list[str] | None = None,
    colors: dict[str, str] | None = None,
) -> None:
    bvals = sorted(agg_df[batch_col].unique())
    n_b = len(bvals)

    dark_levels = np.linspace(0.10, 0.70, n_b) if n_b > 1 else [0.0]
    b_to_dark = {b: dark_levels[i] for i, b in enumerate(bvals)}

    palette = colors or TOOL_COLORS
    order = order or sorted(agg_df[matcher_name_col].unique())

    x = np.arange(len(order))
    total_width = 0.8
    bar_w = total_width / max(n_b, 1)

    plt.figure(figsize=(8, 5))

    for i, b in enumerate(bvals):
        vals = []
        for m in order:
            row = agg_df[(agg_df[matcher_name_col] == m) & (agg_df[batch_col] == b)]
            vals.append(float(row[value_col].iloc[0]) if not row.empty else 0.0)

        offset = -total_width / 2 + (i + 0.5) * bar_w
        bar_colors = [shade_color(palette.get(m, "gray"), b_to_dark[b]) for m in order]

        plt.bar(
            x + offset,
            vals,
            width=bar_w,
            color=bar_colors,
            edgecolor="black",
            linewidth=0.3,
        )

    if log_scale:
        plt.yscale("log")

    plt.xticks(x, order)
    plt.xlabel("Ferramenta")
    plt.ylabel(ylabel)
    if title:
        plt.title(title)
    plt.grid(True, axis="y", linestyle="--", alpha=0.7)

    plt.xlim(-0.6, len(order) - 0.4 + 1.0)

    legend_handles = []
    for i, b in enumerate(bvals):
        gray_val = 1.0 - dark_levels[i]
        gray_color = (gray_val, gray_val, gray_val)
        batch_label = f"{int(b) if float(b).is_integer() else b}"
        patch = mpatches.Patch(
            facecolor=gray_color,
            edgecolor="black",
            linewidth=0.5,
            label=f"batch={batch_label}",
        )
        legend_handles.append(patch)

    plt.legend(
        handles=legend_handles,
        title="Batch size",
        loc="center right",
        bbox_to_anchor=(0.98, 0.5),
    )

    plt.tight_layout()
    save_figure(file_name)
    plt.show()

# %%
def pct95(series: pd.Series) -> float:
    return np.percentile(series, 95)


def get_length_column(df: pd.DataFrame) -> str | None:
    if "total_gt_length" in df.columns:
        return "total_gt_length"
    if "total_added_length" in df.columns:
        return "total_added_length"
    return None


def build_points_per_run(e2e_df: pd.DataFrame) -> pd.DataFrame:
    e2e_pts = e2e_df.copy()
    e2e_pts["cum_points"] = pd.to_numeric(e2e_pts["cum_points"], errors="coerce")
    e2e_pts = e2e_pts.dropna(subset=["run_id", "cum_points"])
    return e2e_pts.groupby("run_id", as_index=False).agg(total_points=("cum_points", "max"))


def build_throughput_runs(
    final_df: pd.DataFrame, e2e_df: pd.DataFrame
) -> tuple[pd.DataFrame, str | None, str | None]:
    length_col = get_length_column(final_df)
    batch_col = None
    if "batch_size_mm" in final_df.columns:
        batch_col = "batch_size_mm"
    elif "batch_size_prom" in final_df.columns:
        batch_col = "batch_size_prom"

    df = final_df.copy()
    df["duration_s"] = pd.to_numeric(df["duration_s"], errors="coerce")
    df = df.dropna(subset=["run_id", "matcher_name", "duration_s"])
    df = df[df["duration_s"] > 0]

    if length_col:
        df[length_col] = pd.to_numeric(df[length_col], errors="coerce")

    points_per_run = build_points_per_run(e2e_df)
    df = df.merge(points_per_run, on="run_id", how="left")
    df = df.dropna(subset=["total_points"])
    df["total_points"] = pd.to_numeric(df["total_points"], errors="coerce")
    df = df[df["total_points"] > 0]

    df["throughput_pps_calc"] = df["total_points"] / df["duration_s"]
    if length_col:
        df["throughput_kmps_calc"] = (df[length_col] / 1000.0) / df["duration_s"]

    return df, length_col, batch_col

# %% [markdown]
# ## Data Loading

# %%
e2e_df = read_csv(E2E_PATH)
e2e_df
# Out:
#                                  run_id matcher_name     mode  step_index  \
# 0      16523baf49f64af2920f43fbc652ea15     graphium   online           0
# 1      16523baf49f64af2920f43fbc652ea15     graphium   online           1
# 2      16523baf49f64af2920f43fbc652ea15     graphium   online           2
# 3      16523baf49f64af2920f43fbc652ea15     graphium   online           3
# 4      16523baf49f64af2920f43fbc652ea15     graphium   online           4
# ...                                 ...          ...      ...         ...
# 14184  15a74036e9fe4f108949b14626cde04e         osrm  offline           2
# 14185  15a74036e9fe4f108949b14626cde04e         osrm  offline           3
# 14186  672439444d6944ccace434e680f85e34         osrm  offline           0
# 14187  672439444d6944ccace434e680f85e34         osrm  offline           1
# 14188  322b1b5b2aa047c0add37a0204e57c70         osrm  offline           0
#
#           timestamp  step_latency_ms  inter_arrival_ms  points_per_step  \
# 0      1.768186e+09      1192.833003               NaN               30
# 1      1.768186e+09       182.609144        182.775974                5
# 2      1.768186e+09       178.779128        178.938150                5
# 3      1.768186e+09       179.915613        180.033445                5
# 4      1.768186e+09       218.816028        218.941450                5
# ...             ...              ...               ...              ...
# 14184  1.768199e+09      3344.208166       3344.361305                5
# 14185  1.768199e+09         0.185594          0.252724                0
# 14186  1.768199e+09      6018.144771               NaN               10
# 14187  1.768199e+09      3344.282321       3344.424009                5
# 14188  1.768199e+09      9360.030614               NaN               15
#
#        cum_points  memory_mb  cpu_time_ms
# 0              30  314.90625         10.0
# 1              35  314.90625          0.0
# 2              40  314.90625          0.0
# 3              45  314.90625          0.0
# 4              50  314.90625          0.0
# ...           ...        ...          ...
# 14184          15  338.75000         10.0
# 14185          15  338.75000          0.0
# 14186          10  338.90625          0.0
# 14187          15  338.90625         10.0
# 14188          15  338.90625          0.0
#
# [14189 rows x 11 columns]

# %%
match_df = read_csv(MATCH_PATH)
match_df
# Out:
#                                run_id  precision    recall  f1_score  \
# 0    9452b53d65ad46e7bca784e891330c42   0.972407  0.913960  0.942278
# 1    318c151658d24539b965db7f45735ab1   0.972407  0.913960  0.942278
# 2    071f4bfd3a6e4ec488709d8baa97955b   0.972407  0.913960  0.942278
# 3    38862d8619234220aa348dcdeb4000e0   0.956736  1.000000  0.977890
# 4    0ce2d2b28c90408f8c0bba7c7d41fac8   0.609645  0.901038  0.727238
# ..                                ...        ...       ...       ...
# 785  b287c480aac74ff880eb803fe05ca937   0.961322  0.869725  0.913232
# 786  1231a2a5a61c4380804ba1984ec75373   0.963249  0.917145  0.939631
# 787  90a68f9b77c4457daf6e1f81e35ded83   0.976326  0.801149  0.880105
# 788  5f44a93a1ec54afe903b447df21c8e38   0.976326  0.801149  0.880105
# 789  b1e81118547742619d368a2ca38a7ea8   0.976867  0.820327  0.891780
#
#      error_rate  accuracy  newson_krumm_error  matched_count  added_count  \
# 0      0.057722  0.890856            0.111975             10            1
# 1      0.057722  0.890856            0.111975             10            1
# 2      0.057722  0.890856            0.111975             10            1
# 3      0.022110  0.956736            0.045220             12            2
# 4      0.272762  0.571386            0.675896             10            7
# ..          ...       ...                 ...            ...          ...
# 785    0.086768  0.840320            0.165268             21            2
# 786    0.060369  0.886137            0.117848             24            2
# 787    0.119895  0.785882            0.218277             18            1
# 788    0.119895  0.785882            0.218277             18            1
# 789    0.108220  0.804695            0.199099             19            1
#
#      missing_count  ...  total_added_length  total_missing_length  vehicle_id  \
# 0                2  ...           17.812997             59.095339        1139
# 1                2  ...           17.812997             59.095339        1139
# 2                2  ...           17.812997             59.095339        1139
# 3                0  ...           31.059085              0.000000        1139
# 4                2  ...          396.259501             67.970605        1139
# ..             ...  ...                 ...                   ...         ...
# 785              8  ...           85.867008            319.680124        1423
# 786              5  ...           85.867008            203.317191        1423
# 787             11  ...           47.669382            487.956680        1423
# 788             11  ...           47.669382            487.956680        1423
# 789             10  ...           47.669382            440.895066        1423
#
#                         experiment_id                       dataset_id  \
# 0    16523baf49f64af2920f43fbc652ea15   ohare_filtered_vid_1139_sr_1.0
# 1    324ea397c7a54ad18e1339fa50aed98c   ohare_filtered_vid_1139_sr_1.0
# 2    565006ebd2e74bf4945c81eb16ab6a1b   ohare_filtered_vid_1139_sr_1.0
# 3    44a75e620a77492daa67aaf769ae6d9c   ohare_filtered_vid_1139_sr_1.0
# 4    a06171e307184813a754e7f5924c407e   ohare_filtered_vid_1139_sr_1.0
# ..                                ...                              ...
# 785  18ce1cb4394346febcc7ae922852a78c  ohare_filtered_vid_1423_sr_20.0
# 786  e9ed28d1b51844e09b87b7243679b2f7  ohare_filtered_vid_1423_sr_20.0
# 787  15a74036e9fe4f108949b14626cde04e  ohare_filtered_vid_1423_sr_20.0
# 788  672439444d6944ccace434e680f85e34  ohare_filtered_vid_1423_sr_20.0
# 789  322b1b5b2aa047c0add37a0204e57c70  ohare_filtered_vid_1423_sr_20.0
#
#     matcher_name     mode  adapter batch_size gps_accuracy
# 0       graphium   online   native        5.0          NaN
# 1       graphium   online   native       10.0          NaN
# 2       graphium   online   native       30.0          NaN
# 3       barefoot   online   native        NaN          NaN
# 4    graphhopper  offline  batches        5.0         50.0
# ..           ...      ...      ...        ...          ...
# 785  graphhopper  offline  batches       10.0         50.0
# 786  graphhopper  offline  batches       30.0         50.0
# 787         osrm  offline  batches        5.0          NaN
# 788         osrm  offline  batches       10.0          NaN
# 789         osrm  offline  batches       30.0          NaN
#
# [790 rows x 22 columns]

# %%
prometheus_df = read_csv(PROMETHEUS_PATH)
prometheus_df
# Out:
#      duration_s   cpu_avg   cpu_max  cpu_total_core_s   mem_avg_mb  \
# 0          15.0  1.643418  2.476856         24.900649  1433.749512
# 1          14.0  1.745557  2.935444         24.904509  1439.782813
# 2          14.0  1.653615  2.772860         23.480448  1446.583854
# 3           7.0  0.378917  0.426825          2.665077   195.839844
# 4          12.0  0.385815  0.726321          4.518585   295.956771
# ..          ...       ...       ...               ...          ...
# 785        18.0  0.274625  0.615558          4.643612   334.392578
# 786        18.0  0.239055  0.732729          4.100579   296.030469
# 787        13.0  0.000343  0.000573          0.004408     3.881836
# 788        12.0  0.000632  0.001066          0.007152     3.032031
# 789        12.0  0.000400  0.001002          0.004415     2.100781
#
#      mem_peak_mb    rx_avg_bps     tx_avg_bps   rx_peak_bps    tx_peak_bps  \
# 0    1492.902344   1225.355153    1726.482962   2708.800000    4123.350000
# 1    1491.480469    709.491711     657.340019   1297.477943    1389.500000
# 2    1493.328125    563.937348     452.448820   1118.050000    1002.225000
# 3     221.234375  16946.145207  152380.020378  19332.196681  209615.798802
# 4     349.316406   1805.716314     987.939743   3221.175000    1865.600000
# ..           ...           ...            ...           ...            ...
# 785   357.375000    287.340894      94.898796    414.849091     228.433333
# 786   313.644531    138.884052       5.228701    299.675724      14.303416
# 787     5.074219    341.472671     573.074571    560.527258     976.078746
# 788     3.917969    296.743839     518.034971    459.656377     884.038180
# 789     2.207031    194.314386       7.219551    298.006667      12.295000
#
#      rx_total_bytes  tx_total_bytes matcher_name     mode  \
# 0      19605.682452    2.762373e+04     graphium   online
# 1      10642.375661    9.860100e+03     graphium   online
# 2       8459.060219    6.786732e+03     graphium   online
# 3     135569.161659    1.219040e+06     barefoot   online
# 4      23474.312085    1.284322e+04  graphhopper  offline
# ..              ...             ...          ...      ...
# 785     5459.476982    1.803077e+03  graphhopper  offline
# 786     2638.796985    9.934533e+01  graphhopper  offline
# 787     4780.617387    8.023044e+03         osrm  offline
# 788     3857.669907    6.734455e+03         osrm  offline
# 789     2526.087013    9.385416e+01         osrm  offline
#
#                           dataset_id                     experiment_id  \
# 0     ohare_filtered_vid_1139_sr_1.0  16523baf49f64af2920f43fbc652ea15
# 1     ohare_filtered_vid_1139_sr_1.0  324ea397c7a54ad18e1339fa50aed98c
# 2     ohare_filtered_vid_1139_sr_1.0  565006ebd2e74bf4945c81eb16ab6a1b
# 3     ohare_filtered_vid_1139_sr_1.0  44a75e620a77492daa67aaf769ae6d9c
# 4     ohare_filtered_vid_1139_sr_1.0  a06171e307184813a754e7f5924c407e
# ..                               ...                               ...
# 785  ohare_filtered_vid_1423_sr_20.0  18ce1cb4394346febcc7ae922852a78c
# 786  ohare_filtered_vid_1423_sr_20.0  e9ed28d1b51844e09b87b7243679b2f7
# 787  ohare_filtered_vid_1423_sr_20.0  15a74036e9fe4f108949b14626cde04e
# 788  ohare_filtered_vid_1423_sr_20.0  672439444d6944ccace434e680f85e34
# 789  ohare_filtered_vid_1423_sr_20.0  322b1b5b2aa047c0add37a0204e57c70
#
#      vehicle_id  adapter  batch_size  gps_accuracy
# 0          1139   native         5.0           NaN
# 1          1139   native        10.0           NaN
# 2          1139   native        30.0           NaN
# 3          1139   native         NaN           NaN
# 4          1139  batches         5.0          50.0
# ..          ...      ...         ...           ...
# 785        1423  batches        10.0          50.0
# 786        1423  batches        30.0          50.0
# 787        1423  batches         5.0           NaN
# 788        1423  batches        10.0           NaN
# 789        1423  batches        30.0           NaN
#
# [790 rows x 20 columns]

# %%
final_runs_df = add_throughput_km_per_s(read_csv(FINAL_PATH))
final_runs_df
# Out:
#      duration_s   cpu_avg   cpu_max  cpu_total_core_s   mem_avg_mb  \
# 0          15.0  1.643418  2.476856         24.900649  1433.749512
# 1          14.0  1.745557  2.935444         24.904509  1439.782813
# 2          14.0  1.653615  2.772860         23.480448  1446.583854
# 3           7.0  0.378917  0.426825          2.665077   195.839844
# 4          12.0  0.385815  0.726321          4.518585   295.956771
# ..          ...       ...       ...               ...          ...
# 785        18.0  0.274625  0.615558          4.643612   334.392578
# 786        18.0  0.239055  0.732729          4.100579   296.030469
# 787        13.0  0.000343  0.000573          0.004408     3.881836
# 788        12.0  0.000632  0.001066          0.007152     3.032031
# 789        12.0  0.000400  0.001002          0.004415     2.100781
#
#      mem_peak_mb    rx_avg_bps     tx_avg_bps   rx_peak_bps    tx_peak_bps  \
# 0    1492.902344   1225.355153    1726.482962   2708.800000    4123.350000
# 1    1491.480469    709.491711     657.340019   1297.477943    1389.500000
# 2    1493.328125    563.937348     452.448820   1118.050000    1002.225000
# 3     221.234375  16946.145207  152380.020378  19332.196681  209615.798802
# 4     349.316406   1805.716314     987.939743   3221.175000    1865.600000
# ..           ...           ...            ...           ...            ...
# 785   357.375000    287.340894      94.898796    414.849091     228.433333
# 786   313.644531    138.884052       5.228701    299.675724      14.303416
# 787     5.074219    341.472671     573.074571    560.527258     976.078746
# 788     3.917969    296.743839     518.034971    459.656377     884.038180
# 789     2.207031    194.314386       7.219551    298.006667      12.295000
#
#      ...  e2e_avg_inter_arrival_ms  e2e_p50_inter_arrival_ms  \
# 0    ...                175.478318                178.727388
# 1    ...                326.990181                351.133585
# 2    ...                955.418507               1043.594599
# 3    ...                 34.580809                 34.567356
# 4    ...                177.236568                181.450248
# ..   ...                       ...                       ...
# 785  ...               3362.779856               3362.779856
# 786  ...                       NaN                       NaN
# 787  ...               2229.577700               3344.119072
# 788  ...               3344.424009               3344.424009
# 789  ...                       NaN                       NaN
#
#     e2e_p75_inter_arrival_ms e2e_p95_inter_arrival_ms  \
# 0                 180.033445               190.009069
# 1                 352.983952               386.070156
# 2                1050.235868              1055.548882
# 3                  35.793304                37.380576
# 4                 182.985961               188.821447
# ..                       ...                      ...
# 785              3362.779856              3362.779856
# 786                      NaN                      NaN
# 787              3344.240189              3344.337082
# 788              3344.424009              3344.424009
# 789                      NaN                      NaN
#
#     e2e_p99_inter_arrival_ms e2e_max_inter_arrival_ms  \
# 0                 213.154974               218.941450
# 1                 402.083569               406.086922
# 2                1056.611485              1056.877136
# 3                  38.146210                39.592743
# 4                 193.970988               195.305347
# ..                       ...                      ...
# 785              3362.779856              3362.779856
# 786                      NaN                      NaN
# 787              3344.356461              3344.361305
# 788              3344.424009              3344.424009
# 789                      NaN                      NaN
#
#      e2e_avg_points_per_step e2e_client_mem_peak_mb  e2e_client_cpu_time_ms  \
# 0                   6.222222             314.906250                    50.0
# 1                  11.200000             328.164062                    40.0
# 2                  28.000000             328.164062                    30.0
# 3                   1.000000             328.476562                   200.0
# 4                   4.869565             328.476562                    90.0
# ..                       ...                    ...                     ...
# 785                 7.500000             338.750000                    10.0
# 786                15.000000             338.750000                    10.0
# 787                 3.750000             338.750000                    10.0
# 788                 7.500000             338.906250                    10.0
# 789                15.000000             338.906250                     0.0
#
#      e2e_throughput_km_per_s
# 0                 230.240177
# 1                 233.386811
# 2                 239.628568
# 3                 178.935032
# 4                 176.147895
# ..                       ...
# 785               729.717334
# 786                      inf
# 787               366.867494
# 788               733.722382
# 789                      inf
#
# [790 rows x 65 columns]

# %% [markdown]
# ## Sanity Checks

# %%
final_runs_df["matcher_name"].value_counts()
# Out:
# matcher_name
# graphhopper    240
# graphium       239
# osrm           231
# barefoot        80
# Name: count, dtype: int64

# %%
graphium_runs = final_runs_df
graphium_runs_zero_time = graphium_runs[graphium_runs["e2e_execution_time_s"] == 0]
graphium_runs_zero_time[["matcher_name", "batch_size_prom", "dataset_id_prom"]].groupby(
    ["matcher_name", "batch_size_prom"]).count()
# Out:
#                               dataset_id_prom
# matcher_name batch_size_prom
# graphhopper  10.0                           5
#              30.0                          35
# graphium     5.0                           36
#              10.0                          36
#              30.0                          36
# osrm         10.0                           5
#              30.0                          35

# %% [markdown]
# ## QP1 — Acurácia por taxa de amostragem
# Nesta seção avaliamos a qualidade do map matching no modo online, comparando F1-score, error_rate e Newson–Krumm por ferramenta e por taxa de amostragem.
#
# Metodologia:
# - derivar `sample_rate` a partir do `dataset_id_prom`;
# - agregar métricas por ferramenta × taxa de amostragem;
# - visualizar tendências com gráficos de linha para F1 e NK error;
# - imprimir a tabela agregada para referência.

# %% [markdown]
# **QP1.** Melhor acurácia no online por taxa de amostragem (média de `accuracy` por ferramenta):

# %%
final_runs_df_agg_full = duckdb.query(
    """
    SELECT
        matcher_name,
        mode,
        adapter_prom AS adapter,
        AVG(e2e_throughput_pps) AS e2e_throughput_pps_avg,
        AVG(e2e_avg_step_latency_ms) AS e2e_avg_step_latency_ms_avg,
        AVG(e2e_p95_step_latency_ms) AS e2e_p95_step_latency_ms_avg,
        AVG(e2e_p99_step_latency_ms) AS e2e_p99_step_latency_ms_avg,
        SUM(e2e_execution_time_s) AS e2e_execution_time_s_sum,
        AVG(cpu_avg) AS sr_cpu_avg,
        AVG(mem_avg_mb) AS sr_mem_mb_avg,
        AVG(accuracy) AS match_accuracy_avg,
        AVG(precision) AS match_precision_avg,
        AVG(recall) AS match_recall_avg,
        AVG(f1_score) AS match_f1_score_avg,
        AVG(error_rate) AS match_error_rate_avg,
        AVG(newson_krumm_error) AS match_newson_krumm_error_avg,
        SUM(total_gt_length) / AVG(e2e_execution_time_s) AS e2e_throughput_km_per_s
    FROM final_runs_df
    GROUP BY matcher_name, mode, adapter
    ORDER BY matcher_name, mode
    """
).to_df()
final_runs_df_agg_full
# Out:
#   matcher_name     mode  adapter  e2e_throughput_pps_avg  \
# 0     barefoot   online   native                9.946762
# 1  graphhopper  offline  batches              552.495259
# 2     graphium   online   native               25.126663
# 3         osrm  offline  batches              614.485738
#
#    e2e_avg_step_latency_ms_avg  e2e_p95_step_latency_ms_avg  \
# 0                   283.347170                   306.046626
# 1                  2854.044491                  3290.542206
# 2                  4671.132345                  5456.121102
# 3                  2910.486628                  3357.487196
#
#    e2e_p99_step_latency_ms_avg  e2e_execution_time_s_sum  sr_cpu_avg  \
# 0                   308.051400                711.058097    0.253312
# 1                  3322.247460               1399.932667    0.286774
# 2                  5700.102711                807.554191    1.296456
# 3                  3383.682416               1288.595020    0.001121
#
#    sr_mem_mb_avg  match_accuracy_avg  match_precision_avg  match_recall_avg  \
# 0     189.891428            0.958685             0.981619          0.975902
# 1     326.453025            0.721862             0.826867          0.824468
# 2    1447.483308            0.904941             0.975432          0.923417
# 3       5.297504            0.813050             0.970129          0.838167
#
#    match_f1_score_avg  match_error_rate_avg  match_newson_krumm_error_avg  \
# 0            0.978118              0.021882                      0.043686
# 1            0.814973              0.185027                      0.380320
# 2            0.946909              0.053091                      0.102184
# 3            0.889189              0.110811                      0.193359
#
#    e2e_throughput_km_per_s
# 0             14945.088059
# 1             68318.595012
# 2            117411.007869
# 3             68526.529831

# %%
final_runs_df_agg_summary = (
    final_runs_df.groupby(["matcher_name", "mode"], as_index=False)
    .agg(
        e2e_throughput_pps=("e2e_throughput_pps", "mean"),
        e2e_avg_step_latency_ms=("e2e_avg_step_latency_ms", "mean"),
        e2e_p95_step_latency_ms=("e2e_p95_step_latency_ms", "mean"),
        e2e_p99_step_latency_ms=("e2e_p99_step_latency_ms", "mean"),
        cpu_avg=("cpu_avg", "mean"),
        mem_avg_mb=("mem_avg_mb", "mean"),
        accuracy=("accuracy", "mean"),
    )
)
final_runs_df_agg_summary
# Out:
#   matcher_name     mode  e2e_throughput_pps  e2e_avg_step_latency_ms  \
# 0     barefoot   online            9.946762               283.347170
# 1  graphhopper  offline          552.495259              2854.044491
# 2     graphium   online           25.126663              4671.132345
# 3         osrm  offline          614.485738              2910.486628
#
#    e2e_p95_step_latency_ms  e2e_p99_step_latency_ms   cpu_avg   mem_avg_mb  \
# 0               306.046626               308.051400  0.253312   189.891428
# 1              3290.542206              3322.247460  0.286774   326.453025
# 2              5456.121102              5700.102711  1.296456  1447.483308
# 3              3357.487196              3383.682416  0.001121     5.297504
#
#    accuracy
# 0  0.958685
# 1  0.721862
# 2  0.904941
# 3  0.813050

# %%
# plot final_runs_df_agg_summary using seaborn
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
axs = axs.flatten()
metrics = [
    "e2e_throughput_pps",
    "e2e_avg_step_latency_ms",
    "cpu_avg",
    "accuracy",
]
titles = [
    "End-to-End Throughput (pps)",
    "End-to-End Average Step Latency (ms)",
    "Average CPU Usage (%)",
    "Accuracy (%)",
]

final_runs_df_agg_summary = final_runs_df_agg_summary.copy()
final_runs_df_agg_summary["label"] = (
    final_runs_df_agg_summary["matcher_name"]
    + " ("
    + final_runs_df_agg_summary["mode"]
    + ")"
)

for i, metric in enumerate(metrics):
    sns.barplot(
        data=final_runs_df_agg_summary,
        x="label",
        y=metric,
        hue="mode",
        ax=axs[i],
    )
    axs[i].set_title(titles[i])
    axs[i].set_ylabel(titles[i])
    axs[i].set_xlabel("")
    axs[i].tick_params(axis="x", rotation=45)
    plt.setp(axs[i].get_xticklabels(), rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
# --------------------------------------------------
# Load data
# --------------------------------------------------
df = add_sample_rate_from_columns(final_runs_df, (SAMPLE_RATE_PROM_COLUMN,))

# --------------------------------------------------
# Extract sample rate from dataset_id_prom
# Example: ohare_filtered_vid_1139_sr_5.0 -> 5.0
# --------------------------------------------------
df = df.dropna(subset=["sample_rate"]).copy()
df["sample_rate"] = df["sample_rate"].astype(float)

# --------------------------------------------------
# Aggregate metrics for QP1
# --------------------------------------------------
qp1_agg = (
    df.groupby(["matcher_name", "sample_rate"], as_index=False)
    .agg(
        f1_mean=("f1_score", "mean"),
        error_rate_mean=("error_rate", "mean"),
        nk_error_mean=("newson_krumm_error", "mean"),
        runs=("f1_score", "count"),
    )
    .sort_values(["matcher_name", "sample_rate"])
)

print(qp1_agg)

# --------------------------------------------------
# Plot 1: F1-score vs sample rate
# --------------------------------------------------
plot_line_by_group(
    qp1_agg,
    x="sample_rate",
    y="f1_mean",
    group="matcher_name",
    xlabel="Sample Rate (s)",
    ylabel="F1-score médio",
    file_name="qp1_f1_vs_sample_rate.pdf",
    order=TOOL_ORDER,
    colors=TOOL_COLORS,
)

# --------------------------------------------------
# Plot 2: Newson-Krumm error vs sample rate
# --------------------------------------------------
plot_line_by_group(
    qp1_agg,
    x="sample_rate",
    y="nk_error_mean",
    group="matcher_name",
    xlabel="Sample Rate (s)",
    ylabel="Newson-Krumm error médio (m)",
    file_name="qp1_nk_error_vs_sample_rate.pdf",
    order=TOOL_ORDER,
    colors=TOOL_COLORS,
)
# Out:
#    matcher_name  sample_rate   f1_mean  error_rate_mean  nk_error_mean  runs
# 0      barefoot          1.0  0.962462         0.037538       0.077555    20
# 1      barefoot          5.0  0.988539         0.011461       0.022625    20
# 2      barefoot         10.0  0.985045         0.014955       0.029302    20
# 3      barefoot         20.0  0.976424         0.023576       0.045261    20
# 4   graphhopper          1.0  0.786160         0.213840       0.488753    60
# 5   graphhopper          5.0  0.864142         0.135858       0.283907    60
# 6   graphhopper         10.0  0.838023         0.161977       0.314321    60
# 7   graphhopper         20.0  0.771570         0.228430       0.434299    60
# 8      graphium          1.0  0.930768         0.069232       0.138932    59
# 9      graphium          5.0  0.937322         0.062678       0.121365    60
# 10     graphium         10.0  0.962715         0.037285       0.069206    60
# 11     graphium         20.0  0.956563         0.043437       0.079846    60
# 12         osrm          1.0  0.946465         0.053535       0.114462    51
# 13         osrm          5.0  0.936886         0.063114       0.119861    60
# 14         osrm         10.0  0.863415         0.136585       0.233089    60
# 15         osrm         20.0  0.818582         0.181418       0.294191    60

# %% [markdown]
# ## QP2 — Eficiência temporal (latência)
# Aqui medimos o tempo de processamento no modo online sob duas visões complementares:
# - latência média por etapa (step latency), agregada por ferramenta e `sample_rate`;
# - tempo total por execução (`duration_s`), que captura o custo completo do processamento.
#
# Para o Graphium, separamos cenários **cold** e **warm** para isolar o impacto do primeiro passo.

# %%
# --------------------------------------------------
# Load data
# --------------------------------------------------
df = add_sample_rate_from_columns(final_runs_df, (SAMPLE_RATE_PROM_COLUMN,))

# --------------------------------------------------
# Extract sample rate from dataset_id_prom
# Example: ohare_filtered_vid_1139_sr_5.0 -> 5.0
# --------------------------------------------------
df = df.dropna(subset=["sample_rate"]).copy()
df["sample_rate"] = df["sample_rate"].astype(float)

# --------------------------------------------------
# QP2: Temporal efficiency (latency) vs sample rate
# Choose one latency metric to be consistent.
# Recommended: e2e_avg_step_latency_ms (average step latency in ms)
# --------------------------------------------------
lat_col = LATENCY_COL

# Keep only rows with latency available (some rows may be missing, e.g., failed runs)
df_lat = df.dropna(subset=[lat_col]).copy()

qp2_agg = (
    df_lat.groupby(["matcher_name", "sample_rate"], as_index=False)
    .agg(
        latency_mean_ms=(lat_col, "mean"),
        runs=(lat_col, "count"),
    )
    .sort_values(["matcher_name", "sample_rate"])
)

print(qp2_agg)

plot_line_by_group(
    qp2_agg,
    x="sample_rate",
    y="latency_mean_ms",
    group="matcher_name",
    xlabel="Sample Rate (s)",
    ylabel="Latência média por etapa (ms)",
    title="Latência média por etapa vs Sample Rate",
    figsize=DEFAULT_FIGSIZE,
    order=TOOL_ORDER,
    colors=TOOL_COLORS,
    file_name="qp2_latency_vs_sample_rate.pdf",
)
# Out:
#    matcher_name  sample_rate  latency_mean_ms  runs
# 0      barefoot          1.0        34.537087    20
# 1      barefoot          5.0       164.426410    20
# 2      barefoot         10.0       320.627659    20
# 3      barefoot         20.0       613.797522    20
# 4   graphhopper          1.0       504.643507    60
# 5   graphhopper          5.0      2100.998934    60
# 6   graphhopper         10.0      3483.444056    60
# 7   graphhopper         20.0      5327.091465    60
# 8      graphium          1.0       434.446059    59
# 9      graphium          5.0      2830.137990    60
# 10     graphium         10.0      6351.712791    60
# 11     graphium         20.0      8997.621100    60
# 12         osrm          1.0       545.608316    51
# 13         osrm          5.0      2061.520280    60
# 14         osrm         10.0      3427.270846    60
# 15         osrm         20.0      5252.815322    60

# %%
# --------------------------------------------------
# Load datasets
# --------------------------------------------------
final_runs_with_sr = add_sample_rate_from_columns(final_runs_df, SAMPLE_RATE_COLUMNS)
e2e_steps_df = e2e_df.copy()

# --------------------------------------------------
# Join E2E steps with run-level metadata
# --------------------------------------------------
meta_cols = ["run_id", "matcher_name_mm", "sample_rate"]
for c in ["batch_size_mm", "dataset_id_mm"]:
    if c in final_runs_with_sr.columns:
        meta_cols.append(c)

df = e2e_steps_df.merge(final_runs_with_sr[meta_cols], on="run_id", how="left")

# Keep only rows we can analyze
df = df.dropna(subset=["matcher_name", "sample_rate", "step_latency_ms"]).copy()

# Ensure numeric
df["sample_rate"] = df["sample_rate"].astype(float)

# --------------------------------------------------
# Build matcher_variant with Graphium cold/warm
# Warm rule:
# - For runs with >1 step: drop step_index == 0
# - For runs with exactly 1 step: keep step_index == 0 (so warm exists)
# --------------------------------------------------
non_graph = df[df["matcher_name"] != "graphium"].copy()
non_graph["matcher_variant"] = non_graph["matcher_name"]

graph = df[df["matcher_name"] == "graphium"].copy()

# Cold = all steps
graph_cold = graph.copy()
graph_cold["matcher_variant"] = "graphium (cold)"

# Determine runs that have only 1 step
# (step_count == 1) OR (max step_index == 0) - both are safe checks
graph_run_steps = (
    graph.groupby("run_id", as_index=False)
    .agg(step_count=("step_index", "count"), max_step=("step_index", "max"))
)
graph = graph.merge(graph_run_steps, on="run_id", how="left")

# Warm selection:
# - if run has only 1 step (max_step == 0 or step_count == 1): keep it
# - else: exclude step 0
warm_mask = (
    (graph["step_count"] == 1)
    | (graph["max_step"] == 0)
    | (graph["step_index"] != 0)
)
graph_warm = graph[warm_mask].copy()
graph_warm["matcher_variant"] = "graphium (warm)"

# Combine dataset for analysis
df_all = pd.concat([non_graph, graph_cold, graph_warm], ignore_index=True)

# --------------------------------------------------
# QP2 aggregation: latency vs sample_rate
# --------------------------------------------------
qp2_sr = (
    df_all.groupby(["matcher_variant", "sample_rate"], as_index=False)
    .agg(
        latency_mean_ms=("step_latency_ms", "mean"),
        steps=("step_latency_ms", "count"),
        runs=("run_id", pd.Series.nunique),
    )
    .sort_values(["matcher_variant", "sample_rate"])
)

print(qp2_sr)

# Plot: latency mean vs sample rate
plot_line_by_group(
    qp2_sr,
    x="sample_rate",
    y="latency_mean_ms",
    group="matcher_variant",
    xlabel="Sample rate (s)",
    ylabel="Latência média por etapa (ms)",
    order=VARIANT_ORDER,
    colors=VARIANT_COLORS,
    file_name="qp2_latency_vs_sample_rate.pdf",
)

# --------------------------------------------------
# QP2 aggregation: latency vs batch_size (if available)
# --------------------------------------------------
batch_col = "batch_size_mm" if "batch_size_mm" in df_all.columns else None

if batch_col:
    df_b = df_all.dropna(subset=[batch_col]).copy()
    df_b[batch_col] = pd.to_numeric(df_b[batch_col], errors="coerce")
    df_b = df_b.dropna(subset=[batch_col])

    qp2_bs = (
        df_b.groupby(["matcher_variant", batch_col], as_index=False)
        .agg(
            latency_mean_ms=("step_latency_ms", "mean"),
            steps=("step_latency_ms", "count"),
            runs=("run_id", pd.Series.nunique),
        )
        .sort_values(["matcher_variant", batch_col])
    )

    print(qp2_bs)

    plot_grouped_bars_by_batch(
        qp2_bs,
        value_col="latency_mean_ms",
        ylabel="Latência média por etapa (ms)",
        matcher_name_col="matcher_variant",
        file_name="qp2_latency_vs_batch_size.pdf",
        colors=VARIANT_COLORS,
        order=[o for o in VARIANT_ORDER if o != "barefoot"],
    )
else:
    print("batch_size_mm não encontrado no metadata; pulei o gráfico por batch size.")
# Out:
#     matcher_variant  sample_rate  latency_mean_ms  steps  runs
# 0          barefoot          1.0        34.617042   5269    20
# 1          barefoot          5.0       165.085977   1072    20
# 2          barefoot         10.0       323.018834    548    20
# 3          barefoot         20.0       622.040391    282    20
# 4       graphhopper          1.0       315.497543   1792    60
# 5       graphhopper          5.0      1394.585863    387    60
# 6       graphhopper         10.0      2495.684464    216    60
# 7       graphhopper         20.0      4194.818088    127    60
# 8   graphium (cold)          1.0       268.713297   2097    59
# 9   graphium (cold)          5.0      1977.633275    276    60
# 10  graphium (cold)         10.0      5807.307656     94    60
# 11  graphium (cold)         20.0      8997.621100     60    60
# 12  graphium (warm)          1.0       243.296723   2038    59
# 13  graphium (warm)          5.0      1329.032961    228    60
# 14  graphium (warm)         10.0      4384.956796     70    60
# 15  graphium (warm)         20.0      8997.621100     60    60
# 16             osrm          1.0       364.599044   1239    51
# 17             osrm          5.0      1370.043084    387    60
# 18             osrm         10.0      2458.176498    216    60
# 19             osrm         20.0      4138.270619    127    60
#     matcher_variant  batch_size_mm  latency_mean_ms  steps  runs
# 0       graphhopper            5.0       492.587831   1481    80
# 1       graphhopper           10.0       954.260315    760    80
# 2       graphhopper           30.0      2569.842172    281    80
# 3   graphium (cold)            5.0       514.753779   1415    79
# 4   graphium (cold)           10.0      1011.400846    726    80
# 5   graphium (cold)           30.0      1897.433011    386    80
# 6   graphium (warm)            5.0       398.059331   1372    79
# 7   graphium (warm)           10.0       807.384684    682    80
# 8   graphium (warm)           30.0      1604.937782    342    80
# 9              osrm            5.0       665.148972    928    71
# 10             osrm           10.0       935.725211    760    80
# 11             osrm           30.0      2526.910941    281    80

# %%
# Escolha a coluna de tempo total disponível
e2e_time_col = E2E_TIME_COL
print(f"Usando coluna de tempo total: {e2e_time_col}")

qp2_e2e = (
    final_runs_with_sr.dropna(subset=["matcher_name_mm", "sample_rate", e2e_time_col])
    .groupby(["matcher_name_mm", "sample_rate"], as_index=False)
    .agg(
        e2e_time_mean_s=(e2e_time_col, "mean"),
        runs=(e2e_time_col, "count"),
    )
    .sort_values(["matcher_name_mm", "sample_rate"])
)

print(qp2_e2e)

# Ajuste nomes pra bater com o seu padrão (matcher_name_mm -> matcher_name)
qp2_e2e = qp2_e2e.rename(columns={"matcher_name_mm": "matcher_name"})
qp2_e2e["matcher_variant"] = qp2_e2e["matcher_name"]  # sem warm/cold aqui

plot_line_by_group(
    qp2_e2e,
    x="sample_rate",
    y="e2e_time_mean_s",
    group="matcher_variant",
    xlabel="Sample rate (s)",
    ylabel="Tempo total médio por execução (s)",
    order=TOOL_ORDER,
    colors=TOOL_COLORS,
    file_name="qp2_e2e_time_vs_sample_rate.pdf",
)
# Out:
# Usando coluna de tempo total: duration_s
#    matcher_name_mm  sample_rate  e2e_time_mean_s  runs
# 0         barefoot          1.0        12.750000    20
# 1         barefoot          5.0        12.350000    20
# 2         barefoot         10.0        12.100000    20
# 3         barefoot         20.0        12.100000    20
# 4      graphhopper          1.0        17.916667    60
# 5      graphhopper          5.0        17.600000    60
# 6      graphhopper         10.0        17.583333    60
# 7      graphhopper         20.0        17.416667    60
# 8         graphium          1.0        19.627119    59
# 9         graphium          5.0        19.033333    60
# 10        graphium         10.0        19.116667    60
# 11        graphium         20.0        18.966667    60
# 12            osrm          1.0        12.254902    51
# 13            osrm          5.0        12.350000    60
# 14            osrm         10.0        12.333333    60
# 15            osrm         20.0        12.100000    60

# %% [markdown]
# ## QP3 — Eficiência computacional (custo vs qualidade)
# Relacionamos qualidade (F1, error_rate) com consumo de CPU e memória. A ideia é observar trade-offs claros entre precisão e custo computacional.
#
# Metodologia:
# - agregar métricas por ferramenta × taxa de amostragem;
# - calcular razões simples (cpu_per_f1 e mem_per_f1);
# - gerar gráficos de custo e um scatter de trade-off qualidade vs CPU.

# %%
# --------------------------------------------------
# Preparar dados (run-level)
# --------------------------------------------------
df = add_sample_rate_from_columns(final_runs_df, SAMPLE_RATE_COLUMNS)

df = df.dropna(subset=["sample_rate", "matcher_name"]).copy()
df["sample_rate"] = df["sample_rate"].astype(float)

# Se quiser focar só no online, descomente:
# df = df[df["mode"].eq("online")].copy()

# --------------------------------------------------
# Agregação QP3: custo + qualidade por ferramenta × sample_rate
# --------------------------------------------------
qp3 = (
    df.groupby(["matcher_name", "sample_rate"], as_index=False)
    .agg(
        # Qualidade
        f1_mean=("f1_score", "mean"),
        err_rate_mean=("error_rate", "mean"),
        nk_err_mean=("newson_krumm_error", "mean"),

        # Custo
        cpu_avg_mean=("cpu_avg", "mean"),
        mem_avg_mean=("mem_avg_mb", "mean"),

        # Opcional
        cpu_total_core_s_mean=("cpu_total_core_s", "mean"),
        mem_peak_mean=("mem_peak_mb", "mean"),

        runs=("run_id", "count"),
    )
    .sort_values(["matcher_name", "sample_rate"])
)

print(qp3)

# --------------------------------------------------
# Métricas simples de custo por qualidade
# --------------------------------------------------
qp3["cpu_per_f1"] = qp3["cpu_avg_mean"] / (qp3["f1_mean"] + EPS)
qp3["mem_per_f1"] = qp3["mem_avg_mean"] / (qp3["f1_mean"] + EPS)

# --------------------------------------------------
# Plot 1: CPU avg vs sample_rate (linhas)
# --------------------------------------------------
plot_line_by_group(
    qp3,
    x="sample_rate",
    y="cpu_avg_mean",
    group="matcher_name",
    xlabel="Sample rate (s)",
    ylabel="CPU média (cpu_avg)",
    order=TOOL_ORDER,
    colors=TOOL_COLORS,
    file_name="qp3_cpu_vs_sample_rate.pdf",
)

# --------------------------------------------------
# Plot 2: Mem avg vs sample_rate (linhas)
# --------------------------------------------------
plot_line_by_group(
    qp3,
    x="sample_rate",
    y="mem_avg_mean",
    group="matcher_name",
    xlabel="Sample rate (s)",
    ylabel="Memória média (MB)",
    order=TOOL_ORDER,
    colors=TOOL_COLORS,
    file_name="qp3_mem_vs_sample_rate.pdf",
)

# --------------------------------------------------
# Plot 3: Qualidade vs CPU (trade-off)
# (cada ponto = uma taxa de amostragem)
# --------------------------------------------------
plt.figure()
annotated_special = False
for name in TOOL_ORDER:
    g = qp3[qp3["matcher_name"] == name]
    if g.empty:
        continue
    plt.scatter(g["cpu_avg_mean"], g["f1_mean"], label=name, color=TOOL_COLORS.get(name))
    for _, row in g.iterrows():
        plt.annotate(
            f"{int(row['sample_rate'])}",
            (row["cpu_avg_mean"], row["f1_mean"]),
            fontsize=7,
            xytext=(4, 0.5),
            textcoords="offset points",
        )
        if (not annotated_special) and ("target_sr" in globals()) and (row["sample_rate"] == target_sr):
            plt.annotate(
                f"taxa de amostragem = {int(row['sample_rate'])} s",
                xy=(row["cpu_avg_mean"], row["f1_mean"]),
                xytext=(30, 30),
                textcoords="offset points",
                arrowprops=dict(arrowstyle="->", color=TOOL_COLORS.get(name)),
                bbox=dict(boxstyle="round,pad=0.3", fc="w", alpha=0.9),
                fontsize=9,
                color=TOOL_COLORS.get(name),
            )
            annotated_special = True

plt.xlabel("CPU média (cpu_avg)")
plt.ylabel("F1-score médio")
plt.legend()
plt.grid(True)
plt.tight_layout()
save_figure("qp3_tradeoff_quality_cpu.svg")
save_figure("qp3_tradeoff_quality_cpu.pdf")
plt.show()
# Out:
#    matcher_name  sample_rate   f1_mean  err_rate_mean  nk_err_mean  \
# 0      barefoot          1.0  0.962462       0.037538     0.077555
# 1      barefoot          5.0  0.988539       0.011461     0.022625
# 2      barefoot         10.0  0.985045       0.014955     0.029302
# 3      barefoot         20.0  0.976424       0.023576     0.045261
# 4   graphhopper          1.0  0.786160       0.213840     0.488753
# 5   graphhopper          5.0  0.864142       0.135858     0.283907
# 6   graphhopper         10.0  0.838023       0.161977     0.314321
# 7   graphhopper         20.0  0.771570       0.228430     0.434299
# 8      graphium          1.0  0.930768       0.069232     0.138932
# 9      graphium          5.0  0.937322       0.062678     0.121365
# 10     graphium         10.0  0.962715       0.037285     0.069206
# 11     graphium         20.0  0.956563       0.043437     0.079846
# 12         osrm          1.0  0.946465       0.053535     0.114462
# 13         osrm          5.0  0.936886       0.063114     0.119861
# 14         osrm         10.0  0.863415       0.136585     0.233089
# 15         osrm         20.0  0.818582       0.181418     0.294191
#
#     cpu_avg_mean  mem_avg_mean  cpu_total_core_s_mean  mem_peak_mean  runs
# 0       0.484943    308.167652               6.489106     448.659570    20
# 1       0.206113    174.970463               2.494428     219.307422    20
# 2       0.170758    151.098541               2.004151     199.832031    20
# 3       0.151436    125.329056               1.785276     173.114453    20
# 4       0.309464    331.230908               5.147650     375.369206    60
# 5       0.290399    328.494609               4.703462     370.427930    60
# 6       0.280607    325.505195               4.546161     367.567773    60
# 7       0.266626    320.581389               4.267185     361.641732    60
# 8       1.347224   1444.637368              25.661778    1487.763440    59
# 9       1.297155   1447.350147              23.999897    1487.024219    60
# 10      1.277557   1448.578529              23.702310    1487.852474    60
# 11      1.264735   1449.319754              23.186504    1488.282422    60
# 12      0.002373     10.906034               0.029963      14.973805    51
# 13      0.000962      4.846890               0.011655       6.469141    60
# 14      0.000722      3.502531               0.008411       4.462435    60
# 15      0.000615      2.775842               0.006683       3.308984    60

# %% [markdown]
# ## QP4 — Throughput (capacidade de processamento)
# Quantificamos a vazão em pontos/s e, quando possível, em km/s. O throughput é calculado a partir de `cum_points` (E2E) e `duration_s`, agregado por ferramenta e `sample_rate`.
#
# Também avaliamos a influência do batch size quando a informação está disponível.

# %%
# -----------------------------
# 1) sample_rate no final_runs_df
# -----------------------------
final_runs_with_sr = add_sample_rate_from_columns(final_runs_df, SAMPLE_RATE_COLUMNS)

throughput_df, length_col, batch_col = build_throughput_runs(final_runs_with_sr, e2e_df)

qp4_df = throughput_df.dropna(subset=["sample_rate"]).copy()
qp4_df["sample_rate"] = qp4_df["sample_rate"].astype(float)

# -----------------------------
# 2) Agregar por ferramenta × sample_rate (inclui p50 e p95)
# -----------------------------
agg_cols = {
    "throughput_pps_mean": ("throughput_pps_calc", "mean"),
    "throughput_pps_p50": ("throughput_pps_calc", "median"),
    "throughput_pps_p95": ("throughput_pps_calc", pct95),
    "runs": ("run_id", "count"),
}
if length_col:
    agg_cols["throughput_kmps_mean"] = ("throughput_kmps_calc", "mean")
    agg_cols["throughput_kmps_p50"] = ("throughput_kmps_calc", "median")
    agg_cols["throughput_kmps_p95"] = ("throughput_kmps_calc", pct95)

qp4_calc = (
    qp4_df.groupby(["matcher_name", "sample_rate"], as_index=False)
    .agg(**agg_cols)
    .sort_values(["matcher_name", "sample_rate"])
)

print(qp4_calc)

# -----------------------------
# 3) Plot: linhas por sample_rate (pps)
# -----------------------------
plot_line_by_group(
    qp4_calc,
    x="sample_rate",
    y="throughput_pps_p95",
    group="matcher_name",
    xlabel="Sample rate (s)",
    ylabel="Throughput p95 (pontos/s)",
    file_name="qp4_throughput_pps_by_sample_rate.pdf",
    colors=TOOL_COLORS,
    order=TOOL_ORDER,
)

# -----------------------------
# 4) Plot: linhas por sample_rate (km/s), se houver length
# -----------------------------
if length_col:
    plot_line_by_group(
        qp4_calc,
        x="sample_rate",
        y="throughput_kmps_p95",
        group="matcher_name",
        xlabel="Sample rate (s)",
        ylabel="Throughput p95 (km/s)",
        file_name="qp4_throughput_kmps_by_sample_rate.pdf",
        colors=TOOL_COLORS,
        order=TOOL_ORDER,
    )
else:
    print("Sem coluna de comprimento (total_gt_length/total_added_length). Pulei km/s.")
# Out:
#    matcher_name  sample_rate  throughput_pps_mean  throughput_pps_p50  \
# 0      barefoot          1.0            19.945986           20.675824
# 1      barefoot          5.0             4.189147            4.375000
# 2      barefoot         10.0             2.194167            2.303846
# 3      barefoot         20.0             1.139323            1.154762
# 4   graphhopper          1.0            14.112535           15.085139
# 5   graphhopper          5.0             2.928427            3.114379
# 6   graphhopper         10.0             1.501456            1.583591
# 7   graphhopper         20.0             0.783700            0.823529
# 8      graphium          1.0            12.880293           13.600000
# 9      graphium          5.0             2.710492            2.894444
# 10     graphium         10.0             1.381021            1.435526
# 11     graphium         20.0             0.719248            0.750000
# 12         osrm          1.0            20.190793           20.923077
# 13         osrm          5.0             4.198568            4.345238
# 14         osrm         10.0             2.155803            2.250000
# 15         osrm         20.0             1.137429            1.166667
#
#     throughput_pps_p95  runs  throughput_kmps_mean  throughput_kmps_p50  \
# 0            23.428571    20              0.125723             0.126176
# 1             4.878750    20              0.129259             0.134775
# 2             2.501667    20              0.132302             0.130812
# 3             1.266970    20              0.132811             0.130882
# 4            17.830159    60              0.088855             0.087300
# 5             3.590857    60              0.090506             0.090359
# 6             1.823427    60              0.090597             0.090417
# 7             0.952839    60              0.091478             0.090417
# 8            16.566234    59              0.081080             0.081753
# 9             3.421970    60              0.083950             0.083238
# 10            1.744767    60              0.083337             0.085229
# 11            0.872383    60              0.083877             0.084617
# 12           23.629808    51              0.128772             0.132063
# 13            4.875000    60              0.129310             0.128268
# 14            2.500000    60              0.129465             0.131951
# 15            1.274476    60              0.132429             0.126974
#
#     throughput_kmps_p95
# 0              0.188978
# 1              0.193682
# 2              0.189720
# 3              0.204664
# 4              0.135179
# 5              0.136625
# 6              0.136625
# 7              0.136625
# 8              0.128742
# 9              0.129453
# 10             0.123801
# 11             0.123479
# 12             0.188760
# 13             0.188978
# 14             0.188978
# 15             0.204490

# %%
# Espera-se que você já tenha calculado `qp4_calc` na célula anterior
# com colunas:
# - matcher_name
# - sample_rate
# - throughput_pps_mean
# - (opcional) throughput_kmps_mean

# -----------------------------
# Line plot: throughput (pps) vs sample_rate
# -----------------------------
plot_line_by_group(
    qp4_calc,
    x="sample_rate",
    y="throughput_pps_mean",
    group="matcher_name",
    xlabel="Sample rate (s)",
    ylabel="Throughput médio (pontos/s)",
    order=TOOL_ORDER,
    colors=TOOL_COLORS,
    file_name="qp4_throughput_pps_vs_sample_rate.pdf",
)

# -----------------------------
# Line plot: throughput (km/s) vs sample_rate (se existir)
# -----------------------------
if "throughput_kmps_mean" in qp4_calc.columns:
    plot_line_by_group(
        qp4_calc,
        x="sample_rate",
        y="throughput_kmps_mean",
        group="matcher_name",
        xlabel="Sample rate (s)",
        ylabel="Throughput médio (km/s)",
        order=TOOL_ORDER,
        colors=TOOL_COLORS,
        file_name="qp4_throughput_kmps_vs_sample_rate.pdf",
    )
else:
    print("Coluna 'throughput_kmps_mean' não encontrada em qp4_calc; pulei o gráfico km/s.")

# %%
# --------------------------------------------------
# 1) Agregar por ferramenta × batch_size
# --------------------------------------------------
if batch_col:
    df_b = throughput_df.dropna(subset=[batch_col]).copy()
    df_b[batch_col] = pd.to_numeric(df_b[batch_col], errors="coerce")
    df_b = df_b.dropna(subset=[batch_col])

    agg_cols = {
        "throughput_pps_mean": ("throughput_pps_calc", "mean"),
        "throughput_pps_p95": ("throughput_pps_calc", pct95),
        "runs": ("run_id", "count"),
    }
    if length_col:
        agg_cols["throughput_kmps_mean"] = ("throughput_kmps_calc", "mean")

    qp4_batch = (
        df_b.groupby(["matcher_name", batch_col], as_index=False)
        .agg(**agg_cols)
        .sort_values(["matcher_name", batch_col])
    )

    print(qp4_batch)

    order = [o for o in TOOL_ORDER if o != "barefoot"]

    # --------------------------------------------------
    # 2) Plot: barras de throughput (pontos/s) vs batch
    # --------------------------------------------------
    plot_grouped_bars_by_batch(
        qp4_batch,
        value_col="throughput_pps_mean",
        ylabel="Throughput médio (pontos/s)",
        batch_col=batch_col,
        file_name="qp4_throughput_pps_by_batch.pdf",
        order=order,
        colors=TOOL_COLORS,
    )

    # --------------------------------------------------
    # 3) Plot: barras de throughput (km/s) vs batch (se existir)
    # --------------------------------------------------
    if "throughput_kmps_mean" in qp4_batch.columns:
        plot_grouped_bars_by_batch(
            qp4_batch,
            value_col="throughput_kmps_mean",
            ylabel="Throughput médio (km/s)",
            batch_col=batch_col,
            log_scale=False,
            file_name="qp4_throughput_kmps_by_batch.pdf",
            order=order,
            colors=TOOL_COLORS,
        )
    else:
        print("Sem coluna de comprimento (total_gt_length/total_added_length). Pulei km/s.")
else:
    print("batch_size_mm/prom não encontrado no metadata; pulei o gráfico por batch size.")
# Out:
#   matcher_name  batch_size_mm  throughput_pps_mean  throughput_pps_p95  runs  \
# 0  graphhopper            5.0             4.798733           16.402727    80
# 1  graphhopper           10.0             4.839558           16.402727    80
# 2  graphhopper           30.0             4.856298           16.774405    80
# 3     graphium            5.0             4.276185           15.262879    79
# 4     graphium           10.0             4.426264           14.942803    80
# 5     graphium           30.0             4.458290           15.633929    80
# 6         osrm            5.0             5.138562           21.086538    71
# 7         osrm           10.0             6.937533           22.340196    80
# 8         osrm           30.0             6.992473           22.662500    80
#
#    throughput_kmps_mean
# 0              0.090005
# 1              0.090759
# 2              0.090314
# 3              0.082713
# 4              0.083055
# 5              0.083436
# 6              0.131028
# 7              0.129423
# 8              0.129784

# %% [markdown]
# # Conclusão
# Os resultados indicam um padrão consistente: **barefoot** se destaca em acurácia e latência no modo online, enquanto **graphium** tende a entregar maior throughput em taxas de amostragem menores. O trade-off custo–qualidade (CPU/memória vs F1) reforça a vantagem do barefoot quando o objetivo é obter precisão com baixo custo computacional.
#
# Em cenários com alta demanda de vazão ou processamento em lote, graphium pode ser competitivo, especialmente quando o aquecimento (warm) é considerado. A escolha final depende do equilíbrio desejado entre precisão, tempo de resposta e capacidade de processamento.
#
# Próximos passos sugeridos:
# - validar as conclusões em datasets adicionais e trajetórias mais diversas;
# - incorporar métricas offline para comparação direta com o modo online;
# - aprofundar a análise de batch size e sensibilidade à taxa de amostragem.
