# %%
from pathlib import Path

import pandas as pd

# %%
DATA_BASE_PATH = Path("./data").resolve().absolute()

# %%
nyc_base_path = DATA_BASE_PATH / "taxi" / "nyc"

fhv_tripdata = pd.read_parquet(nyc_base_path / "fhv_tripdata_2025-01.parquet")
fhvhv_tripdata = pd.read_parquet(nyc_base_path / "fhvhv_tripdata_2025-01.parquet")
green_tripdata = pd.read_parquet(nyc_base_path / "green_tripdata_2025-01.parquet")
yellow_tripdata = pd.read_parquet(nyc_base_path / "yellow_tripdata_2025-01.parquet")

# %%
taxi_zone_lookup = pd.read_csv(nyc_base_path / "taxi_zones" / "taxi_zone_lookup.csv")
taxi_zone_lookup.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
fhv_tripdata.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0               B00009 2025-01-01 00:20:00 2025-01-01 00:57:00           NaN
# 1               B00013 2025-01-01 00:40:00 2025-01-01 02:21:00           NaN
# 2               B00112 2025-01-01 00:22:59 2025-01-01 00:45:28           NaN
# 3               B00112 2025-01-01 00:32:57 2025-01-01 00:33:10           NaN
# 4               B00112 2025-01-01 00:46:48 2025-01-01 00:49:51           NaN
#
#    DOlocationID  SR_Flag Affiliated_base_number
# 0           NaN      NaN                 B00009
# 1           NaN      NaN                 B00888
# 2         108.0      NaN                 B00112
# 3          14.0      NaN                 B00112
# 4          14.0      NaN                 B00112

# %%
fhvhv_tripdata.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0005               B03406                 None
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0003               B03404               B03404
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2025-01-01 00:28:07 2025-01-01 00:31:17 2025-01-01 00:33:25
# 1 2025-01-01 00:18:33                 NaT 2025-01-01 00:29:49
# 2 2025-01-01 00:28:22 2025-01-01 00:31:52 2025-01-01 00:32:39
# 3 2025-01-01 00:27:13 2025-01-01 00:33:58 2025-01-01 00:34:55
# 4 2025-01-01 00:33:29 2025-01-01 00:45:46 2025-01-01 00:46:19
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  \
# 0 2025-01-01 00:54:24           148           211       1.320  ...
# 1 2025-01-01 00:41:52           127           244       3.313  ...
# ...

# %%
green_tripdata.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-01-01 00:03:01   2025-01-01 00:17:12                  N
# 1         2  2025-01-01 00:19:59   2025-01-01 00:25:52                  N
# 2         2  2025-01-01 00:05:29   2025-01-01 00:07:21                  N
# 3         2  2025-01-01 00:52:24   2025-01-01 01:07:52                  N
# 4         2  2025-01-01 00:25:05   2025-01-01 01:01:10                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75           235              1.0           5.93
# 1         1.0           166            75              1.0           1.32
# 2         5.0           171            73              1.0           0.41
# 3         1.0            74           223              1.0           4.12
# 4         1.0            66           158              1.0           4.71
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
yellow_tripdata.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60         1.0                  N           229           237
# 1           0.50         1.0                  N           236           237
# 2           0.60         1.0                  N           141           141
# 3           0.52         1.0                  N           244           244
# 4           0.66         1.0                  N           244           116
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
yellow_tripdata.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee'],
#       dtype='object')
